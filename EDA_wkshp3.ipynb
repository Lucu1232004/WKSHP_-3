# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt

df_2015=pd.read_csv("./CSV WKSHP3/2015.csv")
df_2016=pd.read_csv("./CSV WKSHP3/2016.csv")
df_2017=pd.read_csv("./CSV WKSHP3/2017.csv")
df_2018=pd.read_csv("./CSV WKSHP3/2018.csv")
df_2019=pd.read_csv("./CSV WKSHP3/2019.csv")

# %%
#Hacer cambio de nombres
#Elegir columnas que voy a utilizar
#Hacer funciones del transform
#Pegar en un script de python
#UNIRLOS TODOS

# %%
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# 1              7.509                      7.428                      7.590
# 2              7.501                      7.333                      7.669
# 3              7.498                      7.421                      7.575
# 4              7.413                      7.351                      7.475
# ..               ...                        ...                        ...
# 152            3.484                      3.404                      3.564
# 153            3.360                      3.288                      3.432
# 154            3.303                      3.192                      3.414
# 155            3.069                      2.936                      3.202
# 156            2.905                      2.732                      3.078
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.44178  1.16374                   0.79504  0.57941
# 1                     1.52733  1.14524                   0.86303  0.58557
# 2                     1.42666  1.18326                   0.86733  0.56624
# 3                     1.57744  1.12690                   0.79579  0.59609
# 4                     1.40598  1.13464                   0.81091  0.57104
# ..                        ...      ...                       ...      ...
# 152                   0.39499  0.10419                   0.21028  0.39747
# 153                   0.38227  0.11037                   0.17344  0.16430
# 154                   0.28123  0.00000                   0.24811  0.34678
# 155                   0.74719  0.14866                   0.62994  0.06912
# 156                   0.06831  0.23442                   0.15747  0.04320
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.44453     0.36171            2.73939
# 1                          0.41203     0.28083            2.69463
# 2                          0.14975     0.47678            2.83137
# 3                          0.35776     0.37895            2.66465
# 4                          0.41004     0.25492            2.82596
# ..                             ...         ...                ...
# 152                        0.06681     0.20180            2.10812
# 153                        0.07112     0.31268            2.14558
# 154                        0.11587     0.17517            2.13540
# 155                        0.17233     0.48397            0.81789
# 156                        0.09419     0.20290            2.10404
#
# [157 rows x 13 columns]

# %%
df_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# 1       7.462272                  1.482383  1.551122
# 2       7.385970                  1.480633  1.610574
# 3       7.426227                  1.564980  1.516912
# 4       7.410458                  1.443572  1.540247
# ..           ...                       ...       ...
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.796667  0.635423    0.362012
# 1                    0.792566  0.626007    0.355280
# 2                    0.833552  0.627163    0.475540
# 3                    0.858131  0.620071    0.290549
# 4                    0.809158  0.617951    0.245483
# ..                        ...       ...         ...
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# 152                  0.364509  0.390018    0.354256
# 153                  0.151611  0.059901    0.204435
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 0                         0.315964           2.277027
# 1                         0.400770           2.313707
# 2                         0.153527           2.322715
# 3                         0.367007           2.276716
# 4                         0.382612           2.430182
# ..                             ...                ...
# 150                       0.455220           0.540061
# 151                       0.151347           1.061574
# 152                       0.066035           0.621130
# 153                       0.084148           1.683024
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %%
df_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#
# [156 rows x 9 columns]

# %%
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
#Le añadimos una columna del año, para que en el DF final aparezca
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019

# %%
#Elimino de df_2015 y df_2016 la columna region que me irrelevante
# Elimina la columna "Region" de df_2015
if 'Region' in df_2015.columns:
    df_2015 = df_2015.drop('Region', axis=1)

# Elimina la columna "Region" de df_2016
if 'Region' in df_2016.columns:
    df_2016 = df_2016.drop('Region', axis=1)

# %%
#Ahora le cambio el nombre a las primeros 3 DF's para que al final sea mas facil combinar
df_2015.rename(columns={'Country': 'Country or region'}, inplace=True)
df_2016.rename(columns={'Country': 'Country or region'}, inplace=True)
df_2017.rename(columns={'Country': 'Country or region'}, inplace=True)

# %%
#Cambiamos el nombre de las columnas para que todas queden iguales ya que tienen la misma info
df_2017.rename(columns={'Happiness.Rank': 'Happiness Rank'}, inplace=True)
df_2018.rename(columns={'Overall rank': 'Happiness Rank'}, inplace=True)
df_2019.rename(columns={'Overall rank': 'Happiness Rank'}, inplace=True)

# %%
df_2017.rename(columns={'Happiness.Score': 'Happiness Score'}, inplace=True)
df_2018.rename(columns={'Score': 'Happiness Score'}, inplace=True)
df_2019.rename(columns={'Score': 'Happiness Score'}, inplace=True)

# %%
#Elimino estas columnas ya que no estan en los otros dataframes
if 'Standard Error' in df_2015.columns:
    df_2015 = df_2015.drop('Standard Error', axis=1)

# %%
if 'Lower Confidence Interval' in df_2016.columns:
    df_2016 = df_2016.drop('Lower Confidence Interval', axis=1)
if 'Upper Confidence Interval' in df_2016.columns:
    df_2016 = df_2016.drop('Upper Confidence Interval', axis=1)

# %%
if 'Whisker.high' in df_2017.columns:
    df_2017 = df_2017.drop('Whisker.high', axis=1)
if 'Whisker.low' in df_2017.columns:
    df_2017 = df_2017.drop('Whisker.low', axis=1)

# %%
#Elimino la columna Family
if 'Family' in df_2015.columns:
    df_2015 = df_2015.drop('Family', axis=1)
if 'Family' in df_2016.columns:
    df_2016 = df_2016.drop('Family', axis=1)
if 'Family' in df_2017.columns:
    df_2017 = df_2017.drop('Family', axis=1)

# %%
if 'Happiness Rank' in df_2015.columns:
    df_2015 = df_2015.drop('Happiness Rank', axis=1)
if 'Happiness Rank' in df_2016.columns:
    df_2016 = df_2016.drop('Happiness Rank', axis=1)
if 'Happiness Rank' in df_2017.columns:
    df_2017 = df_2017.drop('Happiness Rank', axis=1)
if 'Happiness Rank' in df_2018.columns:
    df_2018 = df_2018.drop('Happiness Rank', axis=1)
if 'Happiness Rank' in df_2019.columns:
    df_2019 = df_2019.drop('Happiness Rank', axis=1)

# %%
df_2015.rename(columns={'Economy (GDP per Capita)': 'GDP per capita'}, inplace=True)
df_2016.rename(columns={'Economy (GDP per Capita)': 'GDP per capita'}, inplace=True)
df_2017.rename(columns={'Economy..GDP.per.Capita.': 'GDP per capita'}, inplace=True)

# %%
df_2015.rename(columns={'Health (Life Expectancy)': 'Life expectancy'}, inplace=True)
df_2016.rename(columns={'Health (Life Expectancy)': 'Life expectancy'}, inplace=True)
df_2017.rename(columns={'Health..Life.Expectancy.': 'Life expectancy'}, inplace=True)
df_2018.rename(columns={'Healthy life expectancy': 'Life expectancy'}, inplace=True)
df_2019.rename(columns={'Healthy life expectancy': 'Life expectancy'}, inplace=True)

# %%
df_2018.rename(columns={'Freedom to make life choices': 'Freedom'}, inplace=True)
df_2019.rename(columns={'Freedom to make life choices': 'Freedom'}, inplace=True)

# %%
df_2015.rename(columns={'Trust (Government Corruption)': 'Corruption'}, inplace=True)
df_2016.rename(columns={'Trust (Government Corruption)': 'Corruption'}, inplace=True)
df_2017.rename(columns={'Trust..Government.Corruption.': 'Corruption'}, inplace=True)
df_2018.rename(columns={'Perceptions of corruption': 'Corruption'}, inplace=True)
df_2019.rename(columns={'Perceptions of corruption': 'Corruption'}, inplace=True)

# %%
if 'Social support' in df_2018.columns:
    df_2018 = df_2018.drop('Social support', axis=1)
if 'Social support' in df_2019.columns:
    df_2019 = df_2019.drop('Social support', axis=1)

# %%
if 'Dystopia Residual' in df_2015.columns:
    df_2015 = df_2015.drop('Dystopia Residual', axis=1)
if 'Dystopia Residual' in df_2016.columns:
    df_2016 = df_2016.drop('Dystopia Residual', axis=1)
if 'Dystopia.Residual' in df_2017.columns:
    df_2017 = df_2017.drop('Dystopia.Residual', axis=1)

# %%
df_2015
# Out:
#     Country or region  Happiness Score  GDP per capita  Life expectancy  \
# 0         Switzerland            7.587         1.39651          0.94143
# 1             Iceland            7.561         1.30232          0.94784
# 2             Denmark            7.527         1.32548          0.87464
# 3              Norway            7.522         1.45900          0.88521
# 4              Canada            7.427         1.32629          0.90563
# ..                ...              ...             ...              ...
# 153            Rwanda            3.465         0.22208          0.42864
# 154             Benin            3.340         0.28665          0.31910
# 155             Syria            3.006         0.66320          0.72193
# 156           Burundi            2.905         0.01530          0.22396
# 157              Togo            2.839         0.20868          0.28443
#
#      Freedom  Corruption  Generosity  Year
# 0    0.66557     0.41978     0.29678  2015
# 1    0.62877     0.14145     0.43630  2015
# 2    0.64938     0.48357     0.34139  2015
# 3    0.66973     0.36503     0.34699  2015
# 4    0.63297     0.32957     0.45811  2015
# ..       ...         ...         ...   ...
# 153  0.59201     0.55191     0.22628  2015
# 154  0.48450     0.08010     0.18260  2015
# 155  0.15684     0.18906     0.47179  2015
# 156  0.11850     0.10062     0.19727  2015
# 157  0.36453     0.10731     0.16681  2015
#
# [158 rows x 8 columns]

# %%
df_2016
# Out:
#     Country or region  Happiness Score  GDP per capita  Life expectancy  \
# 0             Denmark            7.526         1.44178          0.79504
# 1         Switzerland            7.509         1.52733          0.86303
# 2             Iceland            7.501         1.42666          0.86733
# 3              Norway            7.498         1.57744          0.79579
# 4             Finland            7.413         1.40598          0.81091
# ..                ...              ...             ...              ...
# 152             Benin            3.484         0.39499          0.21028
# 153       Afghanistan            3.360         0.38227          0.17344
# 154              Togo            3.303         0.28123          0.24811
# 155             Syria            3.069         0.74719          0.62994
# 156           Burundi            2.905         0.06831          0.15747
#
#      Freedom  Corruption  Generosity  Year
# 0    0.57941     0.44453     0.36171  2016
# 1    0.58557     0.41203     0.28083  2016
# 2    0.56624     0.14975     0.47678  2016
# 3    0.59609     0.35776     0.37895  2016
# 4    0.57104     0.41004     0.25492  2016
# ..       ...         ...         ...   ...
# 152  0.39747     0.06681     0.20180  2016
# 153  0.16430     0.07112     0.31268  2016
# 154  0.34678     0.11587     0.17517  2016
# 155  0.06912     0.17233     0.48397  2016
# 156  0.04320     0.09419     0.20290  2016
#
# [157 rows x 8 columns]

# %%
df_2017
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 0                      Norway            7.537        1.616463
# 1                     Denmark            7.522        1.482383
# 2                     Iceland            7.504        1.480633
# 3                 Switzerland            7.494        1.564980
# 4                     Finland            7.469        1.443572
# ..                        ...              ...             ...
# 150                    Rwanda            3.471        0.368746
# 151                     Syria            3.462        0.777153
# 152                  Tanzania            3.349        0.511136
# 153                   Burundi            2.905        0.091623
# 154  Central African Republic            2.693        0.000000
#
#      Life expectancy   Freedom  Generosity  Corruption  Year
# 0           0.796667  0.635423    0.362012    0.315964  2017
# 1           0.792566  0.626007    0.355280    0.400770  2017
# 2           0.833552  0.627163    0.475540    0.153527  2017
# 3           0.858131  0.620071    0.290549    0.367007  2017
# 4           0.809158  0.617951    0.245483    0.382612  2017
# ..               ...       ...         ...         ...   ...
# 150         0.326425  0.581844    0.252756    0.455220  2017
# 151         0.500533  0.081539    0.493664    0.151347  2017
# 152         0.364509  0.390018    0.354256    0.066035  2017
# 153         0.151611  0.059901    0.204435    0.084148  2017
# 154         0.018773  0.270842    0.280876    0.056565  2017
#
# [155 rows x 8 columns]

# %%
df_2018
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 0                     Finland            7.632           1.305
# 1                      Norway            7.594           1.456
# 2                     Denmark            7.555           1.351
# 3                     Iceland            7.495           1.343
# 4                 Switzerland            7.487           1.420
# ..                        ...              ...             ...
# 151                     Yemen            3.355           0.442
# 152                  Tanzania            3.303           0.455
# 153               South Sudan            3.254           0.337
# 154  Central African Republic            3.083           0.024
# 155                   Burundi            2.905           0.091
#
#      Life expectancy  Freedom  Generosity  Corruption  Year
# 0              0.874    0.681       0.202       0.393  2018
# 1              0.861    0.686       0.286       0.340  2018
# 2              0.868    0.683       0.284       0.408  2018
# 3              0.914    0.677       0.353       0.138  2018
# 4              0.927    0.660       0.256       0.357  2018
# ..               ...      ...         ...         ...   ...
# 151            0.343    0.244       0.083       0.064  2018
# 152            0.381    0.481       0.270       0.097  2018
# 153            0.177    0.112       0.224       0.106  2018
# 154            0.010    0.305       0.218       0.038  2018
# 155            0.145    0.065       0.149       0.076  2018
#
# [156 rows x 8 columns]

# %%
df_2019
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 0                     Finland            7.769           1.340
# 1                     Denmark            7.600           1.383
# 2                      Norway            7.554           1.488
# 3                     Iceland            7.494           1.380
# 4                 Netherlands            7.488           1.396
# ..                        ...              ...             ...
# 151                    Rwanda            3.334           0.359
# 152                  Tanzania            3.231           0.476
# 153               Afghanistan            3.203           0.350
# 154  Central African Republic            3.083           0.026
# 155               South Sudan            2.853           0.306
#
#      Life expectancy  Freedom  Generosity  Corruption  Year
# 0              0.986    0.596       0.153       0.393  2019
# 1              0.996    0.592       0.252       0.410  2019
# 2              1.028    0.603       0.271       0.341  2019
# 3              1.026    0.591       0.354       0.118  2019
# 4              0.999    0.557       0.322       0.298  2019
# ..               ...      ...         ...         ...   ...
# 151            0.614    0.555       0.217       0.411  2019
# 152            0.499    0.417       0.276       0.147  2019
# 153            0.361    0.000       0.158       0.025  2019
# 154            0.105    0.225       0.235       0.035  2019
# 155            0.295    0.010       0.202       0.091  2019
#
# [156 rows x 8 columns]

# %%
df_unido = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)
df_unido
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 0                 Switzerland            7.587         1.39651
# 1                     Iceland            7.561         1.30232
# 2                     Denmark            7.527         1.32548
# 3                      Norway            7.522         1.45900
# 4                      Canada            7.427         1.32629
# ..                        ...              ...             ...
# 777                    Rwanda            3.334         0.35900
# 778                  Tanzania            3.231         0.47600
# 779               Afghanistan            3.203         0.35000
# 780  Central African Republic            3.083         0.02600
# 781               South Sudan            2.853         0.30600
#
#      Life expectancy  Freedom  Corruption  Generosity  Year
# 0            0.94143  0.66557     0.41978     0.29678  2015
# 1            0.94784  0.62877     0.14145     0.43630  2015
# 2            0.87464  0.64938     0.48357     0.34139  2015
# 3            0.88521  0.66973     0.36503     0.34699  2015
# 4            0.90563  0.63297     0.32957     0.45811  2015
# ..               ...      ...         ...         ...   ...
# 777          0.61400  0.55500     0.41100     0.21700  2019
# 778          0.49900  0.41700     0.14700     0.27600  2019
# 779          0.36100  0.00000     0.02500     0.15800  2019
# 780          0.10500  0.22500     0.03500     0.23500  2019
# 781          0.29500  0.01000     0.09100     0.20200  2019
#
# [782 rows x 8 columns]

# %%
#Sacamos el df del csv unido
df_unido.to_csv("df_unido.csv", index=False)

# %%
# Identificar valores faltantes
print(df_unido.isnull().sum())
# Out:
# Country or region    0
# Happiness Score      0
# GDP per capita       0
# Life expectancy      0
# Freedom              0
# Corruption           1
# Generosity           0
# Year                 0
# dtype: int64

# %%
# Eliminar filas con valores faltantes
df_unido = df_unido.dropna()
print(df_unido.isnull().sum())
# Out:
# Country or region    0
# Happiness Score      0
# GDP per capita       0
# Life expectancy      0
# Freedom              0
# Corruption           0
# Generosity           0
# Year                 0
# dtype: int64

# %%
df_unido
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 0                 Switzerland            7.587         1.39651
# 1                     Iceland            7.561         1.30232
# 2                     Denmark            7.527         1.32548
# 3                      Norway            7.522         1.45900
# 4                      Canada            7.427         1.32629
# ..                        ...              ...             ...
# 777                    Rwanda            3.334         0.35900
# 778                  Tanzania            3.231         0.47600
# 779               Afghanistan            3.203         0.35000
# 780  Central African Republic            3.083         0.02600
# 781               South Sudan            2.853         0.30600
#
#      Life expectancy  Freedom  Corruption  Generosity  Year
# 0            0.94143  0.66557     0.41978     0.29678  2015
# 1            0.94784  0.62877     0.14145     0.43630  2015
# 2            0.87464  0.64938     0.48357     0.34139  2015
# 3            0.88521  0.66973     0.36503     0.34699  2015
# 4            0.90563  0.63297     0.32957     0.45811  2015
# ..               ...      ...         ...         ...   ...
# 777          0.61400  0.55500     0.41100     0.21700  2019
# 778          0.49900  0.41700     0.14700     0.27600  2019
# 779          0.36100  0.00000     0.02500     0.15800  2019
# 780          0.10500  0.22500     0.03500     0.23500  2019
# 781          0.29500  0.01000     0.09100     0.20200  2019
#
# [781 rows x 8 columns]

# %%
df_unido.head()
# Out:
#   Country or region  Happiness Score  GDP per capita  Life expectancy  \
# 0       Switzerland            7.587         1.39651          0.94143
# 1           Iceland            7.561         1.30232          0.94784
# 2           Denmark            7.527         1.32548          0.87464
# 3            Norway            7.522         1.45900          0.88521
# 4            Canada            7.427         1.32629          0.90563
#
#    Freedom  Corruption  Generosity  Year
# 0  0.66557     0.41978     0.29678  2015
# 1  0.62877     0.14145     0.43630  2015
# 2  0.64938     0.48357     0.34139  2015
# 3  0.66973     0.36503     0.34699  2015
# 4  0.63297     0.32957     0.45811  2015

# %%
df_unido.tail()
# Out:
#             Country or region  Happiness Score  GDP per capita  \
# 777                    Rwanda            3.334           0.359
# 778                  Tanzania            3.231           0.476
# 779               Afghanistan            3.203           0.350
# 780  Central African Republic            3.083           0.026
# 781               South Sudan            2.853           0.306
#
#      Life expectancy  Freedom  Corruption  Generosity  Year
# 777            0.614    0.555       0.411       0.217  2019
# 778            0.499    0.417       0.147       0.276  2019
# 779            0.361    0.000       0.025       0.158  2019
# 780            0.105    0.225       0.035       0.235  2019
# 781            0.295    0.010       0.091       0.202  2019

# %%
df_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 781 entries, 0 to 781
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country or region  781 non-null    object
#  1   Happiness Score    781 non-null    float64
#  2   GDP per capita     781 non-null    float64
#  3   Life expectancy    781 non-null    float64
#  4   Freedom            781 non-null    float64
#  5   Corruption         781 non-null    float64
#  6   Generosity         781 non-null    float64
#  7   Year               781 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 54.9+ KB

# %%
df_unido.describe()
# Out:
#        Happiness Score  GDP per capita  Life expectancy     Freedom  \
# count       781.000000      781.000000       781.000000  781.000000
# mean          5.377232        0.914537         0.612342    0.411254
# std           1.127071        0.405403         0.248459    0.152911
# min           2.693000        0.000000         0.000000    0.000000
# 25%           4.509000        0.605000         0.440060    0.310480
# 50%           5.321000        0.982000         0.647239    0.431000
# 75%           6.182000        1.233748         0.808000    0.531000
# max           7.769000        1.870766         1.141000    0.724000
#
#        Corruption  Generosity         Year
# count  781.000000  781.000000   781.000000
# mean     0.125436    0.218618  2016.992318
# std      0.105816    0.122394     1.417814
# min      0.000000    0.000000  2015.000000
# 25%      0.054000    0.130000  2016.000000
# 50%      0.091000    0.202000  2017.000000
# 75%      0.156030    0.279060  2018.000000
# max      0.551910    0.838075  2019.000000

# %%
df_unido.describe().round(2)
# Out:
#        Happiness Score  GDP per capita  Life expectancy  Freedom  Corruption  \
# count           781.00          781.00           781.00   781.00      781.00
# mean              5.38            0.91             0.61     0.41        0.13
# std               1.13            0.41             0.25     0.15        0.11
# min               2.69            0.00             0.00     0.00        0.00
# 25%               4.51            0.60             0.44     0.31        0.05
# 50%               5.32            0.98             0.65     0.43        0.09
# 75%               6.18            1.23             0.81     0.53        0.16
# max               7.77            1.87             1.14     0.72        0.55
#
#        Generosity     Year
# count      781.00   781.00
# mean         0.22  2016.99
# std          0.12     1.42
# min          0.00  2015.00
# 25%          0.13  2016.00
# 50%          0.20  2017.00
# 75%          0.28  2018.00
# max          0.84  2019.00

# %%
import pandas as pd
import matplotlib.pyplot as plt
años = df_unido['Year']
años_enteros = años.astype(int)
plt.figure(figsize=(12, 6))
conteo_por_año = años_enteros.value_counts().sort_index()
plt.bar(range(len(conteo_por_año)), conteo_por_año, color='skyblue')
plt.xlabel('Índice del Año')
plt.ylabel('Frecuencia')
plt.title('Distribución de Años en el DataFrame')
plt.xticks(range(len(conteo_por_año)), conteo_por_año.index, rotation=45)
plt.show()

# %%
Year= df_unido['Year'].value_counts()
Year
# Out:
# Year
# 2015    158
# 2016    157
# 2019    156
# 2017    155
# 2018    155
# Name: count, dtype: int64

# %%
cantidad = df_unido.dtypes.value_counts()
cantidad.index = cantidad.index.astype(str)


cantidad.plot(kind='bar')
plt.title('Tipos de Datos en el DataFrame')
plt.xlabel('Tipo de Dato')
plt.ylabel('Cantidad de Columnas')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
Country= df_unido['Country or region'].value_counts()
Country
# Out:
# Country or region
# Switzerland                 5
# Dominican Republic          5
# Greece                      5
# Lebanon                     5
# Hungary                     5
#                            ..
# Taiwan Province of China    1
# Somaliland Region           1
# Djibouti                    1
# Oman                        1
# Gambia                      1
# Name: count, Length: 170, dtype: int64

# %%
df_unido.count()
# Out:
# Country or region    781
# Happiness Score      781
# GDP per capita       781
# Life expectancy      781
# Freedom              781
# Corruption           781
# Generosity           781
# Year                 781
# dtype: int64

# %%
df_unido.max()
# Out:
# Country or region    Zimbabwe
# Happiness Score         7.769
# GDP per capita       1.870766
# Life expectancy         1.141
# Freedom                 0.724
# Corruption            0.55191
# Generosity           0.838075
# Year                     2019
# dtype: object

# %%
df_unido.min()
# Out:
# Country or region    Afghanistan
# Happiness Score            2.693
# GDP per capita               0.0
# Life expectancy              0.0
# Freedom                      0.0
# Corruption                   0.0
# Generosity                   0.0
# Year                        2015
# dtype: object

# %%
df_numerico = df_unido.select_dtypes(include=['number'])
correlation_matrix = df_numerico.corr(numeric_only=True)
correlation_matrix
# Out:
#                  Happiness Score  GDP per capita  Life expectancy   Freedom  \
# Happiness Score         1.000000        0.789719         0.742843  0.553365
# GDP per capita          0.789719        1.000000         0.787752  0.345615
# Life expectancy         0.742843        0.787752         1.000000  0.341155
# Freedom                 0.553365        0.345615         0.341155  1.000000
# Corruption              0.398418        0.306307         0.250512  0.459593
# Generosity              0.138142       -0.013646         0.010718  0.290564
# Year                    0.005946        0.017230         0.130138  0.011118
#
#                  Corruption  Generosity      Year
# Happiness Score    0.398418    0.138142  0.005946
# GDP per capita     0.306307   -0.013646  0.017230
# Life expectancy    0.250512    0.010718  0.130138
# Freedom            0.459593    0.290564  0.011118
# Corruption         1.000000    0.318920 -0.122264
# Generosity         0.318920    1.000000 -0.192416
# Year              -0.122264   -0.192416  1.000000

# %%
df_unido.groupby('Country or region').mean()
# Out:
#                    Happiness Score  GDP per capita  Life expectancy   Freedom  \
# Country or region
# Afghanistan                3.51280        0.357113         0.254707  0.117924
# Albania                    4.71260        0.938633         0.787696  0.371898
# Algeria                    5.66760        1.012963         0.665057  0.178437
# Angola                     3.87225        0.798380         0.133902  0.027433
# Argentina                  6.45940        1.111035         0.760895  0.481620
# ...                            ...             ...              ...       ...
# Venezuela                  5.53140        1.052468         0.683741  0.213709
# Vietnam                    5.15460        0.723416         0.722700  0.577207
# Yemen                      3.62580        0.489313         0.365440  0.244175
# Zambia                     4.58440        0.571761         0.302761  0.462099
# Zimbabwe                   4.00660        0.344051         0.274403  0.323257
#
#                    Corruption  Generosity    Year
# Country or region
# Afghanistan          0.058094    0.267730  2017.0
# Albania              0.043201    0.167887  2017.0
# Algeria              0.146099    0.069219  2017.0
# Angola               0.071570    0.105269  2016.5
# Argentina            0.064308    0.092371  2017.0
# ...                       ...         ...     ...
# Venezuela            0.071444    0.057186  2017.0
# Vietnam              0.091921    0.195664  2017.0
# Yemen                0.067045    0.096929  2017.0
# Zambia               0.097337    0.218430  2017.0
# Zimbabwe             0.089997    0.169409  2017.0
#
# [170 rows x 7 columns]

# %%
#Matriz de gráficos de dispersión y gráficos de densidad de kernel
#Son útiles para visualizar la distribución de una variable en lugar de un histograma.

# %%
sns.pairplot(df_unido, diag_kind="kde")

# %%
#La correlación entre parametros indica si existe una relación estadística entre las variables y cómo se comportan juntas.
#Para hacer esta tabla necesitamos solo usar valores númericos ya que los que son tipo Object no se pueden agregar

# %%
df_numerico = df_unido.select_dtypes(include=['number'])
sns.heatmap(df_numerico.corr(), annot=True, fmt='.2g', cmap='flare')
plt.title("Correlación entre parámetros")
plt.show()

# %%
#Instalamos esta libreria para hacer más graficos como el de Regresión lineal

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(df_unido.columns)
# Out:
# Index(['Country or region', 'Happiness Score', 'GDP per capita',
#        'Life expectancy', 'Freedom', 'Corruption', 'Generosity', 'Year'],
#       dtype='object')

# %%
df_unido.dtypes
# Out:
# Country or region     object
# Happiness Score      float64
# GDP per capita       float64
# Life expectancy      float64
# Freedom              float64
# Corruption           float64
# Generosity           float64
# Year                   int64
# dtype: object

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\samuel\appdata\local\programs\python\python312\lib\site-packages (1.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import joblib

X = df_unido[['GDP per capita', 'Life expectancy', 'Freedom']]
y = df_unido['Happiness Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

joblib_file = "modelo_regresion.pkl"
joblib.dump(model, joblib_file)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
plt.scatter(y_test, y_pred)
plt.xlabel('Happiness Score Real')
plt.ylabel('Happiness Score Predicho')
plt.title('Predicciones vs. Realidad')
plt.show()
# Out:
# Mean Squared Error: 0.3410903598884471
# R-squared: 0.7268417050999556

# %%
#Finalmente tenemos el grafico de dispersión, en donde el eje x muestra los valores reales de Happiness score y el eje y muestra las predicciones
